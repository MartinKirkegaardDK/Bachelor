# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

list1 = [0.44, 0.23, 0.23, 0.06]
list2 = [0.58, 0.44, 0.44, 0.47]

fig, ax = plt.subplots()

bar_width = 0.4
x_pos = [i for i in range(len(list1))]
x_pos2 = [x + bar_width for x in x_pos]

ax.bar(x_pos, list1, color='blue', label='Linear regression', width=bar_width)
ax.bar(x_pos2, list2, color='red', label='Random Forest', width=bar_width)

ax.set_xlabel('Distance Metrics')
ax.set_ylabel('R-squared score')
ax.set_title('R-squared score of Different Models using Distance Metrics')
ax.set_xticks([i + bar_width/2 for i in x_pos])
ax.set_xticklabels(['Cosine', 'Eucledian', 'Manhatten', 'Heterogeneous'])
ax.legend()

plt.show()
plt.savefig("pictures_for_rapport/r2_comp_dist")

# %%
import pandas as pd

df = pd.read_csv("martin_runs/merged_df.csv")

# %%
# Best rf on all data without dist
condition = (df["dataset"] == 'all') & (df["with_distance"] == True) & (df["model_name"] == 'RandomForestRegressor()')
rf_df = df[condition]


result = rf_df.sort_values('mean_test_score', ascending=False)
result = result.iloc[[0]]
result.iloc[0][0]
# Out:
# "{'rf__criterion': 'squared_error', 'rf__max_depth': None}"

# %%
result.iloc[0][0]
# Out:
# "{'rf__criterion': 'squared_error', 'rf__max_depth': None}"

# %%
# Best rf on all data without dist
condition = (df["dataset"] == 'all') & (df["with_distance"] == True) & (df["model_name"] == 'RandomForestRegressor()')
rf_df = df[condition]


result = rf_df.sort_values('mean_test_score', ascending=False)
result = result.iloc[[0]]
result.iloc[0][0]
# Out:
# "{'rf__criterion': 'squared_error', 'rf__max_depth': None}"

# %%
# Best rf on all data without dist
condition = (df["dataset"] == 'ManDist') & (df["with_distance"] == True) & (df["model_name"] == 'RandomForestRegressor()')
rf_df = df[condition]


result = rf_df.sort_values('mean_test_score', ascending=False)
#result = result.iloc[[0]]
result
# Out:
#                                                 params  mean_test_score  \
# 577  {'PCA__n_components': 16, 'rf__criterion': 'sq...         0.582210
# 573  {'PCA__n_components': 14, 'rf__criterion': 'sq...         0.569984
# 5    {'rf__criterion': 'squared_error', 'rf__max_de...         0.566533
# 569  {'PCA__n_components': 12, 'rf__criterion': 'sq...         0.552538
# 565  {'PCA__n_components': 10, 'rf__criterion': 'sq...         0.541330
# ..                                                 ...              ...
# 620  {'PCA__n_components': 36, 'rf__criterion': 'sq...              NaN
# 621  {'PCA__n_components': 38, 'rf__criterion': 'sq...              NaN
# 622  {'PCA__n_components': 38, 'rf__criterion': 'sq...              NaN
# 623  {'PCA__n_components': 38, 'rf__criterion': 'sq...              NaN
# 624  {'PCA__n_components': 38, 'rf__criterion': 'sq...              NaN
#
#      dataset           model_file_name  \
# 577  ManDist  martin_models/test_1.pkl
# ...

# %%
# Best rf on all data without dist
condition = (df["dataset"] == 'Dist') & (df["with_distance"] == True) & (df["model_name"] == 'RandomForestRegressor()')
rf_df = df[condition]


result = rf_df.sort_values('mean_test_score', ascending=False)
result = result.iloc[[0]]
result.iloc[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1587, in _iLocIndexer._get_list_axis(self, key, axis)
#    1586 try:
# -> 1587     return self.obj._take_with_is_copy(key, axis=axis)
#    1588 except IndexError as err:
#    1589     # re-raise with different error message
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:3902, in NDFrame._take_with_is_copy(self, indices, axis)
#    3895 """
#    3896 Internal version of the `take` method that sets the `_is_copy`
#    3897 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3900 See the docstring of `take` for full explanation of the parameters.
#    3901 """
# -> 3902 result = self._take(indices=indices, axis=axis)
#    3903 # Maybe set copy if we didn't actually change the index.
#
# ...

# %%
import pandas as pd
dist = pd.read_csv("data/distance_data/processed_distances.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Density Plot and Histogram of all arrival delays
ax = sns.distplot(dist['0'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

ax.set_xlabel("Dinstance in km")

ax.set_ylabel("count")
ax.set_title("Distribution of the geographical distance")
# Out:
# /var/folders/jv/cmw96wbs0_72bmk_p4vxvdy40000gn/T/ipykernel_16730/3934827803.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dist['0'], hist=True, kde=True,
# Text(0.5, 1.0, 'Distribution of the geographical distance')

# %%
# matplotlib histogram
plt.hist(dist['0'], color = 'blue', edgecolor = 'black',
         bins = int(180/2))
# Out:
# (array([ 54., 101., 110., 150., 187., 172., 181., 216., 181., 194., 185.,
#         156., 175., 191., 194., 198., 187., 233., 224., 213., 248., 283.,
#         281., 278., 234., 297., 225., 283., 270., 259., 266., 242., 238.,
#         271., 298., 321., 290., 279., 280., 286., 262., 235., 232., 242.,
#         207., 206., 233., 177., 181., 203., 152., 154., 155., 175., 168.,
#         149., 170., 152., 143., 148., 144., 145., 154., 116., 119., 118.,
#          95., 105., 112., 100., 112., 108., 104.,  83.,  99.,  85.,  65.,
#          71.,  50.,  81.,  51.,  53.,  53.,  44.,  33.,  24.,  24.,  16.,
#           7.,   5.]),
#  array([   59.61723   ,   280.63437189,   501.65151378,   722.66865567,
#           943.68579756,  1164.70293944,  1385.72008133,  1606.73722322,
#          1827.75436511,  2048.771507  ,  2269.78864889,  2490.80579078,
#          2711.82293267,  2932.84007456,  3153.85721644,  3374.87435833,
# ...
